# %%
import os
import pandas as pd
import numpy as np

# %%
os.chdir(r'C:\Users\jaij2\OneDrive\바탕 화면\논문\야구데이터\전처리')
df_19 = pd.read_csv('2019_타자_Saber.csv', encoding = 'cp949')
df_19.index = df_19['Name']
del df_19['Name']
df_19 = df_19[df_19['PA'] >= 144]
df_19 = df_19.drop(['RC', 'RC27', 'PSR'], axis = 1)
df_19
# Out:
#        PA   AB  RBI  RUN  HIT  H2  H3  HR  SB  CS  ...       OBP       SLG  \
# Name                                               ...
# 이대호   549  485   88   48  138  23   1  16   0   0  ...  0.355191  0.435052
# 박병호   532  432   98   92  121  22   0  33   0   1  ...  0.398496  0.560185
# 양의지   459  390   68   61  138  26   0  20   4   3  ...  0.437908  0.574359
# 손아섭   568  512   63   78  151  22   1  10  13   8  ...  0.359788  0.400391
# 최형우   555  456   86   65  137  31   1  17   0   1  ...  0.412613  0.484649
# ...   ...  ...  ...  ...  ...  ..  ..  ..  ..  ..  ...       ...       ...
# 나종덕   209  185   13   12   23   4   0   3   0   0  ...  0.188119  0.194595
# 허일    162  149   17   14   38   4   0   1   2   1  ...  0.314815  0.302013
# 이우성   168  151   22   19   33   4   0   6   0   0  ...  0.281437  0.364238
# 오윤석   228  198   21   21   44   2   0   1   0   0  ...  0.294643  0.247475
# 노시환   192  177   13   19   33   8   1   1   2   2  ...  0.240838  0.259887
#
# ...

# %%
df_19['wOBA']
# Out:
# Name
# 이대호    0.639070
# 박병호    0.770666
# 양의지    0.802156
# 손아섭    0.588717
# 최형우    0.698233
#          ...
# 나종덕    1.335876
# 허일     1.629840
# 이우성    1.649287
# 오윤석    1.197368
# 노시환    1.409419
# Name: wOBA, Length: 106, dtype: float64
